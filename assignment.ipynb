# %% [markdown]
# # Assignment Solutions
# Based on uploaded PDF.

# %% [markdown]
# ## Q1: What is a VectorDB?
# A vector database stores embeddings etc...

# %% [markdown]
# ## Q6: Chroma sample code

# %%
from chromadb import Client
client = Client()
collection = client.create_collection('test')
collection.add(documents=['hello'], ids=['1'], embeddings=[[0.1,0.2,0.3]])
collection.query(query_embeddings=[[0.1,0.2,0.3]], n_results=1)
